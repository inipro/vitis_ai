# %%
from google.colab import drive
drive.mount('/content/drive/')
import os
os.chdir('/content/drive/My Drive/vitis_ai/CIFAR10-Classification-with-TensorFlow')

# %%
# %tensorflow_version 1.x

# %%
# !mkdir -p ./build/logs
# !python train.py --input_height 32 --input_width 32 --input_chan 3 --epochs 100 --learnrate 0.0001 --batchsize 50 \
    --output_ckpt_path ./build/chkpts/float_model.ckpt --infer_graph_path ./build/chkpts/inference_graph.pb --tboard_path ./build/tb_logs
