# %%
from google.colab import drive
drive.mount('/content/drive/')
import os
os.chdir('/content/drive/My Drive/vitis_ai/DenseNetX_DPUv2')

# %%
# !pip install keras==2.2.4

# %%
# %tensorflow_version 1.x

# %%
# !mkdir -p build/keras_model
# !mkdir -p build/logs
# !python train.py --input_height 32 --input_width 32 --input_chan 3 --epochs 100 --learnrate 0.001 --batchsize 150 --tboard ./build/tb_logs --keras_hdf5 ./build/keras_model/k_model.h5
