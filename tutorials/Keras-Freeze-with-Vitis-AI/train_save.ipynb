# %%
from google.colab import drive
drive.mount('/content/drive/')
import os
os.chdir('/content/drive/My Drive/vitis_ai/Keras-Freeze-with-Vitis-AI')

# %%
# !pip install keras==2.2.4

# %%
# %tensorflow_version 1.x

# %%
# !python train_save.py
