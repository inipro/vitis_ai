# %%
from google.colab import drive
drive.mount('/content/drive/')
import os
os.chdir('/content/drive/My Drive/vitis_ai/MNIST-Classification-TensorFlow')

# %%
# %tensorflow_version 1.x

# %%
# !mkdir -p ./build/logs
# !python train.py --input_height 28 --input_width 28 --input_chan 1 --epochs 50 --learnrate 0.0001 --batchsize 100 \
    --output_ckpt_path ./build/chkpts/float_model.ckpt --infer_graph_path ./build/chkpts/inference_graph.pb --tboard_path ./build/tb_logs
